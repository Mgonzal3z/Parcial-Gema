# %% [markdown]
# <a href="https://colab.research.google.com/github/Mgonzal3z/Parcial-Gema/blob/main/ParcialCorte2_SI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate
# !pip install -U transformers
# !pip install twilio requests
# !pip install Flask==3.0.0 pyngrok==7.1.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 60.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import os
os.environ["HUGGINGFACE_HUB_TOKEN"] = "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"
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it",token="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")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it",token="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", device_map="auto")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/888 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Gemma's activation function should be approximate GeLU and not exact GeLU.
# Changing the activation function to `gelu_pytorch_tanh`.if you want to use the legacy `gelu`, edit the `model.config` to set `hidden_activation=gelu`   instead of `hidden_act`. See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
def charla(text):
    input_ids = tokenizer(text, return_tensors="pt").to("cuda")
    max_new_tokens = 50
    outputs = model.generate(**input_ids,max_new_tokens=max_new_tokens)
    return tokenizer.decode(outputs[0],skip_special_tokens=True, pad_token_id=tokenizer.bos_token_id)

# %%
print(charla("make a poem about colombia"))
# Out:
# make a poem about colombia's vibrant culture and traditions
#
# Colombian culture is a vibrant tapestry,
# Woven with traditions that have spanned.
# From the bustling streets to the tranquil shores,
# A culture that's rich, forevermore.
#
# The vibrant colors

# %%
ngrok_key = "2chIcfX69FwfIRZVxAsl9gtsIYn_5B5ZQMBYBGSQXgLeHAjtM"
port= 5000

# %%
from pyngrok import ngrok

ngrok.set_auth_token(ngrok_key)
ngrok.connect(port).public_url
# Out:
# Exception in thread Thread-12 (_monitor_process):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pyngrok/process.py", line 140, in _monitor_process
#     self._log_line(self.proc.stdout.readline())
#   File "/usr/lib/python3.10/encodings/ascii.py", line 26, in decode
#     return codecs.ascii_decode(input, self.errors)[0]
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 184: ordinal not in range(128)
# 'https://783f-34-147-88-29.ngrok-free.app'

# %%
from flask import Flask, request
import requests
from twilio.twiml.messaging_response import Message, MessagingResponse

app = Flask(__name__)

@app.route('/', methods=['POST'])
def bot():
    incoming_msg = request.values.get('Body', '').lower()
    print("\n===========================")
    print("MENSAJE RECIBIDO: ", incoming_msg)
    print("===========================")
    response  = MessagingResponse()
    msg = response.message()
    responded = False
    text = charla(incoming_msg);
    print("MENSAJE A ENVIAR: ", text)
    print("===========================")
    msg.body(text)
    responded = True
    return str(response)

if __name__ == '__main__':
    app.run(port= 5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# ...
# MENSAJE RECIBIDO:  me puedes dar información sobre vuelos a españa
# ...
# INFO:werkzeug:127.0.0.1 - - [02/Apr/2024 21:43:56] "POST / HTTP/1.1" 200 -
# MENSAJE A ENVIAR:  me puedes dar información sobre vuelos a españa?
#
# **Información sobre vuelos a España:**
#
# * **Número de vuelos:** Más de 200 vuelos por día desde más de 150 destinos.
# * **Duración:** Las vuelos suelen durar entre 6 y 12
# ...
#
# ...
# MENSAJE RECIBIDO:  estas conectado a internet?
# ...
# INFO:werkzeug:127.0.0.1 - - [02/Apr/2024 21:47:22] "POST / HTTP/1.1" 200 -
# MENSAJE A ENVIAR:  estas conectado a internet?
#
# Sim,estas conectados a internet. Elas podem acessar e enviar dados, como texto, imagens e vídeos, através da internet.
# ...
#
# ...
